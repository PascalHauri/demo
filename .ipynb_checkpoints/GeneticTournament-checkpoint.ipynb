# %%
# !pip install --upgrade pip
# !pip install folium
# !pip install ipython-autotime
# !pip install output

import pandas as pd
pd.set_option("display.max_rows", None)
pd.options.display.max_columns = None

import folium
from folium import plugins
# %matplotlib inline
import random, operator
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %load_ext autotime
# %pdb  # debugin
# Out:
# Requirement already up-to-date: pip in /anaconda3/lib/python3.7/site-packages (19.1.1)
# Requirement already satisfied: folium in /anaconda3/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: branca>=0.3.0 in /anaconda3/lib/python3.7/site-packages (from folium) (0.3.1)
# Requirement already satisfied: jinja2 in /anaconda3/lib/python3.7/site-packages (from folium) (2.10.1)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from folium) (1.16.3)
# Requirement already satisfied: requests in /anaconda3/lib/python3.7/site-packages (from folium) (2.21.0)
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.7/site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: ipython-autotime in /anaconda3/lib/python3.7/site-packages (0.1)
# Requirement already satisfied: output in /anaconda3/lib/python3.7/site-packages (1.0.1)
# <style>.container { width:100% !important; }</style>
# Incorrect argument. Use on/1, off/0, or nothing for a toggle.

# %%
# read in jobs for one day
JobsInTime=pd.DataFrame([['16', 48, 14.8],
       ['22', 49, 25.0],
       ['28', 50, 74.8],
       ['22', 51, 59.8],
       ['22', 52, 59.8],
       ['71', 53, 25.0],
       ['28', 54, 95.2],
       ['28', 55, 35.2],
       ['71', 56, 25.0],
       ['29', 57, 40.0],
       ['28', 58, 29.8],
       ['29', 59, 50.2],
       ['64', 60, 35.2],
       ['28', 61, 55.0],
       ['29', 62, 29.8],
       ['22', 63, 70.0],
       ['28', 64, 40.0],
       ['28', 65, 35.2],
       ['16', 66, 40.0],
       ['16', 67, 29.8],
       ['16', 68, 85.0],
       ['17', 69, 55.0],
       ['77', 70, 40.0],
       ['29', 71, 70.0],
       ['29', 72, 40.0],
       ['23', 73, 29.8],
       ['22', 74, 40.0],
       ['22', 75, 40.0],
       ['22', 76, 25.0],
       ['16', 77, 59.8],
       ['70', 78, 44.8],
       ['23', 79, 44.8],
       ['22', 80, 29.8],
       ['28', 81, 40.0],
       ['16', 82, 40.0],
       ['16', 83, 25.0],
       ['70', 84, 50.2],
       ['23', 85, 55.0],
       ['17', 86, 59.8],
       ['73', 87, 50.2],
       ['28', 88, 70.0],
       ['17', 89, 40.0],
       ['77', 90, 29.8],
       ['71', 91, 40.0],
       ['76', 92, 25.0],
       ['23', 93, 35.0],
       ['16', 94, 25.0],
       ['64', 95, 44.8],
       ['73', 96, 50.2],
       ['29', 97, 44.8],
       ['28', 98, 25.0],
       ['73', 99, 25.0],
       ['65', 100, 55.0],
       ['22', 101, 40.0],
       ['77', 102, 25.0],
       ['23', 103, 55.0],
       ['16', 104, 59.8],
       ['17', 105, 40.0],
       ['65', 106, 29.8],
       ['16', 107, 80.2],
       ['29', 108, 25.0],
       ['76', 109, 32.8],
       ['17', 110, 50.2],
       ['22', 111, 35.2],
       ['76', 112, 40.0],
       ['16', 113, 40.0],
       ['22', 114, 23.8],
       ['22', 115, 35.2],
       ['28', 116, 50.2],
       ['70', 117, 50.2],
       ['29', 118, 35.2],
       ['77', 119, 25.0],
       ['28', 120, 29.8],
       ['29', 121, 50.2],
       ['76', 122, 35.2],
       ['71', 123, 25.0],
       ['70', 124, 59.8],
       ['29', 125, 44.8],
       ['29', 126, 29.8],
       ['28', 127, 40.0],
       ['28', 128, 25.0],
       ['16', 129, 25.0],
       ['28', 130, 40.0],
       ['28', 131, 19.0],
       ['76', 132, 55.0],
       ['70', 133, 25.0],
       ['22', 134, 35.2],
       ['22', 135, 30.0],
       ['28', 136, 55.0],
       ['70', 137, 65.0],
       ['28', 138, 56.2],
       ['28', 139, 50.2],
       ['29', 140, 50.2],
       ['23', 141, 80.0],
       ['23', 142, 40.0],
       ['70', 143, 29.8],
       ['17', 144, 29.8],
       ['28', 145, 44.8],
       ['23', 146, 89.8],
       ['16', 147, 29.8],
       ['17', 148, 55.0],
       ['28', 149, 25.0],
       ['28', 150, 40.0],
       ['22', 151, 25.0],
       ['23', 152, 44.8],
       ['29', 153, 74.8],
       ['22', 154, 20.2],
       ['22', 155, 50.0],
       ['17', 156, 25.0],
       ['77', 157, 40.0],
       ['64', 158, 29.8],
       ['74', 159, 50.2],
       ['22', 160, 20.2],
       ['22', 161, 35.2],
       ['17', 162, 40.0],
       ['28', 163, 35.2],
       ['23', 164, 40.0],
       ['70', 165, 44.8],
       ['22', 166, 80.2],
       ['29', 167, 25.0],
       ['29', 168, 25.0],
       ['16', 169, 74.8],
       ['77', 170, 35.2],
       ['70', 171, 40.0],
       ['28', 172, 44.8],
       ['28', 173, 25.0],
       ['22', 174, 25.0],
       ['76', 175, 70.0],
       ['29', 176, 55.0],
       ['22', 177, 25.0],
       ['29', 178, 55.0],
       ['28', 179, 55.0],
       ['16', 180, 25.0],
       ['16', 181, 44.8],
       ['22', 182, 29.8],
       ['76', 183, 32.8],
       ['16', 184, 40.0],
       ['28', 185, 80.0],
       ['28', 186, 25.0],
       ['17', 187, 29.8],
       ['28', 188, 25.0],
       ['64', 189, 59.8],
       ['70', 190, 50.2],
       ['29', 191, 25.0],
       ['16', 192, 70.0],
       ['29', 193, 29.8],
       ['28', 194, 40.0],
       ['17', 195, 115.0],
       ['77', 196, 40.0],
       ['70', 197, 35.2],
       ['28', 198, 40.0],
       ['76', 199, 55.0],
       ['76', 200, 44.8],
       ['28', 201, 35.2],
       ['23', 202, 28.0],
       ['22', 203, 44.8],
       ['16', 204, 30.0],
       ['29', 205, 74.8],
       ['76', 206, 35.2],
       ['70', 207, 130.0],
       ['77', 208, 25.0],
       ['22', 209, 70.0],
       ['29', 210, 40.0],
       ['77', 211, 70.0],
       ['22', 212, 40.0],
       ['77', 213, 70.0],
       ['17', 214, 59.8],
       ['22', 215, 38.2],
       ['16', 216, 50.2],
       ['16', 217, 40.0],
       ['28', 218, 100.0],
       ['47', 219, 29.8],
       ['17', 220, 55.0],
       ['29', 221, 25.0],
       ['70', 222, 37.0],
       ['76', 223, 40.0],
       ['17', 224, 25.0],
       ['17', 225, 40.0],
       ['22', 226, 59.8],
       ['22', 227, 59.8],
       ['70', 228, 50.2],
       ['29', 229, 80.2],
       ['70', 230, 40.0],
       ['28', 231, 40.0],
       ['70', 232, 40.0],
       ['22', 233, 25.0],
       ['16', 234, 40.0],
       ['28', 235, 40.0],
       ['64', 236, 70.0],
       ['22', 237, 29.8],
       ['28', 238, 89.8],
       ['71', 239, 29.8],
       ['22', 240, 35.0],
       ['29', 241, 50.2],
       ['70', 242, 70.0],
       ['29', 243, 55.0],
       ['70', 244, 62.8],
       ['29', 245, 35.2],
       ['22', 246, 50.2],
       ['77', 247, 40.0],
       ['23', 248, 70.0],
       ['28', 249, 35.2],
       ['28', 250, 50.2],
       ['28', 251, 35.2],
       ['22', 252, 95.0],
       ['74', 253, 74.8],
       ['77', 254, 25.0],
       ['74', 255, 100.0],
       ['22', 256, 29.8],
       ['77', 257, 35.2],
       ['23', 258, 70.0],
       ['74', 259, 44.8],
       ['22', 260, 70.0],
       ['28', 261, 44.8],
       ['70', 262, 70.0],
       ['28', 263, 25.0],
       ['71', 264, 34.0],
       ['29', 265, 55.0],
       ['29', 266, 59.8],
       ['74', 267, 40.0],
       ['17', 268, 25.0],
       ['77', 269, 40.0],
       ['16', 270, 29.8]])
JobsInTime.columns = ['LX_TCK_RP', 'indexJobLocation', 'a.jobDuration']
JobsInTime
# Out:
#     LX_TCK_RP  indexJobLocation  a.jobDuration
# 0          16                48           14.8
# 1          22                49           25.0
# 2          28                50           74.8
# 3          22                51           59.8
# 4          22                52           59.8
# 5          71                53           25.0
# 6          28                54           95.2
# 7          28                55           35.2
# 8          71                56           25.0
# 9          29                57           40.0
# 10         28                58           29.8
# 11         29                59           50.2
# 12         64                60           35.2
# 13         28                61           55.0
# 14         29                62           29.8
# 15         22                63           70.0
# 16         28                64           40.0
# 17         28                65           35.2
# 18         16                66           40.0
# 19         16                67           29.8
# 20         16                68           85.0
# 21         17                69           55.0
# 22         77                70           40.0
# 23         29                71           70.0
# 24         29                72           40.0
# 25         23                73           29.8
# 26         22                74           40.0
# 27         22                75           40.0
# 28         22                76           25.0
# 29         16                77           59.8
# 30         70                78           44.8
# 31         23                79           44.8
# 32         22                80           29.8
# 33         28                81           40.0
# 34         16                82           40.0
# 35         16                83           25.0
# 36         70                84           50.2
# 37         23                85           55.0
# 38         17                86           59.8
# 39         73                87           50.2
# 40         28                88           70.0
# 41         17                89           40.0
# 42         77                90           29.8
# 43         71                91           40.0
# 44         76                92           25.0
# 45         23                93           35.0
# 46         16                94           25.0
# 47         64                95           44.8
# 48         73                96           50.2
# 49         29                97           44.8
# 50         28                98           25.0
# 51         73                99           25.0
# 52         65               100           55.0
# 53         22               101           40.0
# 54         77               102           25.0
# 55         23               103           55.0
# 56         16               104           59.8
# 57         17               105           40.0
# 58         65               106           29.8
# 59         16               107           80.2
# 60         29               108           25.0
# 61         76               109           32.8
# 62         17               110           50.2
# 63         22               111           35.2
# 64         76               112           40.0
# 65         16               113           40.0
# 66         22               114           23.8
# 67         22               115           35.2
# 68         28               116           50.2
# 69         70               117           50.2
# 70         29               118           35.2
# 71         77               119           25.0
# 72         28               120           29.8
# 73         29               121           50.2
# 74         76               122           35.2
# 75         71               123           25.0
# 76         70               124           59.8
# 77         29               125           44.8
# 78         29               126           29.8
# 79         28               127           40.0
# 80         28               128           25.0
# 81         16               129           25.0
# 82         28               130           40.0
# 83         28               131           19.0
# 84         76               132           55.0
# 85         70               133           25.0
# 86         22               134           35.2
# 87         22               135           30.0
# 88         28               136           55.0
# 89         70               137           65.0
# 90         28               138           56.2
# 91         28               139           50.2
# 92         29               140           50.2
# 93         23               141           80.0
# 94         23               142           40.0
# 95         70               143           29.8
# 96         17               144           29.8
# 97         28               145           44.8
# 98         23               146           89.8
# 99         16               147           29.8
# 100        17               148           55.0
# 101        28               149           25.0
# 102        28               150           40.0
# 103        22               151           25.0
# 104        23               152           44.8
# 105        29               153           74.8
# 106        22               154           20.2
# 107        22               155           50.0
# 108        17               156           25.0
# 109        77               157           40.0
# 110        64               158           29.8
# 111        74               159           50.2
# 112        22               160           20.2
# 113        22               161           35.2
# 114        17               162           40.0
# 115        28               163           35.2
# 116        23               164           40.0
# 117        70               165           44.8
# 118        22               166           80.2
# 119        29               167           25.0
# 120        29               168           25.0
# 121        16               169           74.8
# 122        77               170           35.2
# 123        70               171           40.0
# 124        28               172           44.8
# 125        28               173           25.0
# 126        22               174           25.0
# 127        76               175           70.0
# 128        29               176           55.0
# 129        22               177           25.0
# 130        29               178           55.0
# 131        28               179           55.0
# 132        16               180           25.0
# 133        16               181           44.8
# 134        22               182           29.8
# 135        76               183           32.8
# 136        16               184           40.0
# 137        28               185           80.0
# 138        28               186           25.0
# 139        17               187           29.8
# 140        28               188           25.0
# 141        64               189           59.8
# 142        70               190           50.2
# 143        29               191           25.0
# 144        16               192           70.0
# 145        29               193           29.8
# 146        28               194           40.0
# 147        17               195          115.0
# 148        77               196           40.0
# 149        70               197           35.2
# 150        28               198           40.0
# 151        76               199           55.0
# 152        76               200           44.8
# 153        28               201           35.2
# 154        23               202           28.0
# 155        22               203           44.8
# 156        16               204           30.0
# 157        29               205           74.8
# 158        76               206           35.2
# 159        70               207          130.0
# 160        77               208           25.0
# 161        22               209           70.0
# 162        29               210           40.0
# 163        77               211           70.0
# 164        22               212           40.0
# 165        77               213           70.0
# 166        17               214           59.8
# 167        22               215           38.2
# 168        16               216           50.2
# 169        16               217           40.0
# 170        28               218          100.0
# 171        47               219           29.8
# 172        17               220           55.0
# 173        29               221           25.0
# 174        70               222           37.0
# 175        76               223           40.0
# 176        17               224           25.0
# 177        17               225           40.0
# 178        22               226           59.8
# 179        22               227           59.8
# 180        70               228           50.2
# 181        29               229           80.2
# 182        70               230           40.0
# 183        28               231           40.0
# 184        70               232           40.0
# 185        22               233           25.0
# 186        16               234           40.0
# 187        28               235           40.0
# 188        64               236           70.0
# 189        22               237           29.8
# 190        28               238           89.8
# 191        71               239           29.8
# 192        22               240           35.0
# 193        29               241           50.2
# 194        70               242           70.0
# 195        29               243           55.0
# 196        70               244           62.8
# 197        29               245           35.2
# 198        22               246           50.2
# 199        77               247           40.0
# 200        23               248           70.0
# 201        28               249           35.2
# 202        28               250           50.2
# 203        28               251           35.2
# 204        22               252           95.0
# 205        74               253           74.8
# 206        77               254           25.0
# 207        74               255          100.0
# 208        22               256           29.8
# 209        77               257           35.2
# 210        23               258           70.0
# 211        74               259           44.8
# 212        22               260           70.0
# 213        28               261           44.8
# 214        70               262           70.0
# 215        28               263           25.0
# 216        71               264           34.0
# 217        29               265           55.0
# 218        29               266           59.8
# 219        74               267           40.0
# 220        17               268           25.0
# 221        77               269           40.0
# 222        16               270           29.8
# time: 54.8 ms

# %%
# read in technicians (available at this day)
TechForCalc=pd.DataFrame([["[18 17 16 15 14 21 20 27 28]['23' '71' '77' '17' '29' '74' '64' '76' '65' '47' '22']",
        0],
       ["[18 17 16 15 14 19 21 20 29 28 27]['23' '71' '16' '76' '22' '29' '28' '70' '77' '65' '17' '73' '64' '46']",
        1],
       ["[18 17 16 15 19 21 20 28 27]['29' '77' '23' '71' '74' '65' '76' '22' '70' '64' '47']",
        2],
       ["[20 27 29 28 18 17 16 15 14 13 12 19 21]['28' '22' '64' '70' '16' '76' '29' '73' '77' '74' '23' '17' nan]",
        3],
       ["[18 17 16 15 14 13 12 19 21 20 28 27]['22' '29' '71' '77' '23' '74' '64' '17' '65' '47' '28' '16']",
        4],
       ["[18 17 16 15 19 21 20 29 28 27]['23' '29' '46' '22' '77' '64' '76' '65' '70' '47' '71' '74' '28' '17']",
        5],
       ["[18 17 16 15 19 21 20 28 27]['29' '77' '65' '71' '23' '47' '22' '28' '76' '17' '74']",
        6],
       ["[18 17 16 15 19 21 20 29 28 27]['22' '28' '76' '77' '70' '73' '29' '46' '16']",
        7],
       ["[18 17 16 15 19 21 20 29 28 27]['29' '77' '85' '73' '70' '23' '47' '28' '22' '65' '71' '16' '76']",
        8],
       ["[18 17 16 15 14 19 21 20 27 29 28]['76' '22' '70' '17' '16' '71' '29' '28' '64' '73' '65' '23' '47' '74']",
        9],
       ["[18 17 16 15 19 21 20 29 28 27]['76' '22' '70' '28' '29' '77' '23' '71' '73' '74']",
        10],
       ["[18 17 16 15 14 13 12 19 21 20 27 28 23]['74' '77' '29' '71' '17' '23' '47' '22' '70' '16' '65']",
        11],
       ["[18 17 16 15 14 13 12 19 21 20 26 25 27 29 28]['22' '70' '76' '16' '28' '73' '64' '17']",
        12],
       ["[18 17 16 15 14 19 21 20 28 27]['70' '23' '77' '29' '71' '28' '17' '65' '16' '22' '74' '76']",
        13],
       ["[18 17 16 15 14 19 21 20 29 28 27]['16' '22' '28' '76' '70' '77' '23' '46' '64' '73' '17']",
        14],
       ["[18 17 16 15 14 13 12 19 21 20 29 28 27]['76' '22' '16' '28' '64' '70' '17' '73' '71' '47' '29']",
        15],
       ["[18 17 16 15 19 21 20 29 28 27]['64' '76' '28' '22' '70' '46' '23' '16' '71']",
        16],
       ["[18 17 16 15 14 19 21 20 29 28 27 23]['22' '71' '77' '29' '17' '65' '46' '16' '28' '23' '74' '64' '70' '76']",
        17],
       ["[18 17 16 15 19 21 20 29 28 27]['28' '22' '29' '70' '76' '23' '71' '64' '74' '77' '73']",
        18],
       ["[18 17 16 15 19 21 20 29 28 27]['16' '28' '29' '22' '74' '64' '71' '47' '23' '76' '70' '77' '73']",
        19],
       ["[18 17 16 15 14 19 21 20 28 27]['16' '71' '29' '65' '77' '70' '74' '17' '23' '47' '22' '28' '64' '73']",
        20],
       ["[18 17 16 15 19 21 20 29 27]['28' '70' '22' '76' '64' '74' '73' '77' '16' '29' '47']",
        21],
       ["[18 17 16 15 19 21 20 29 28 27]['28' '22' '70' '23' '76' '73' '29' '71' '64' '16']",
        22],
       ["[18 17 16 15 14 19 21 20 28 27]['74' '23' '29' '71' '77' '65' '17' '22' '28' '70' '47']",
        23],
       ["[18 17 16 15 14 19 21 20 28 27]['17' '23' '71' '77' '29' '74' '28' '22' '65']",
        24],
       ["[16 14 29 27 18 17 15 26 25]['16' '28' '64' '70' '76' '73' '71' '29' '17']",
        25],
       ["[18 17 16 15 14 19 21 20 29 28 27]['22' '70' '16' '64' '46' '73' '76' '28' '17' '29' '23']",
        26],
       ["[18 17 16 15 19 21 20 23 29 28 27]['22' '70' '28' '76' '23' '64' '46' '65' '73' '77' '29']",
        27],
       ["[18 17 16 15 14 19 21 20 29 28 27]['70' '17' '29' '23' '28' '65' '76' '16' '64' '73' '22' '77' '71']",
        28],
       ["[18 17 16 15 14 19 21 20 29 28 27]['22' '76' '28' '70' '23' '64' '77' '73' '29' '46']",
        29],
       ["[18 17 16 15 19 21 20 29 28 27]['22' '28' '76' '16' '64' '70' '73' '29' '85' '17']",
        30],
       ["[18 17 16 15 19 21 20 29 28 27]['28' '22' '76' '64' '46' '16' '73' '74' '70' '29' '23' '77']",
        31],
       ["[18 17 16 15 19 21 29 28 27]['22' '70' '76' '64' '28' '73' '29']",
        32],
       ["[16 18 17 15 19 21]['28' '71' '73' '70' '22' '76' '64' '46' '65' '77' '29' '74']",
        33],
       ["[18 17 16 15 19 21 20 29 27]['22' '76' '28' '70' '77' '73' '23' '46' '71' '64' '29']",
        34],
       ["[18 17 16 15 29 28 27]['28' '76' '29' '71' '22' '64' '70' '16' '73' '77']",
        35],
       ["[18 17 16 15 19 21 20 29 27]['64' '28' '76' '22' '70' '77' '29' '73' '71' nan]",
        36],
       ["[18 17 16 15 29 28 27]['71' '28' '22' '29' '77' '70' '23' '76' '73' '46' '47']",
        37],
       ["[18 17 16 15 29 28 27]['28' '29' '70' '22' '76' '46' '77' '64' '65' '71' '74' '47' '23']",
        38],
       ["[18 17 16 15 14 19 21 20 28 27]['71' '23' '74' '29' '17' '77' '65' '22' '28']",
        39],
       ["[18 17 16 15 14 19 21 20 29 28 27 23]['16' '22' '28' '71' '77' '70' '76' '17' '23' '73' '29' '64']",
        40],
       ["[18 17 16 15 29 27 19 21]['76' '28' '64' '29' '73' '82' '22' '71' '70' '65']",
        41],
       ["[18 17 16 15 14 19 21 20 27 29]['76' '28' '22' '70' '64' '23' '29' '77' '73']",
        42],
       ["[18 17 16 29 28 27]['77' '70' '29' '65' '71' '23' '76' '28' '64' '74']",
        43],
       ["[18 17 16 15 14 13 12 19 21 20 27 29 28]['28' '16' '29' '76' '70' '22' '23' '73' '64' '46' '82' '19' '71' nan]",
        44],
       ["[18 17 16 15 14 19 21 27 29 28 20]['16' '29' '28' '17' '22']",
        45],
       ["[18 17 16 15 19 21  4 29]['28' '22' '70' '73' '76' '77' '29' '23' '71' '64']",
        46],
       ["[18 17 15 19 21 29 20 27]['76' '22' '28' '73' '70' '64']", 47]])

TechForCalc.columns=["PRI_QUALIF","indexHomeLocation"]
TechForCalc
# Out:
#                                            PRI_QUALIF  indexHomeLocation
# 0   [18 17 16 15 14 21 20 27 28]['23' '71' '77' '1...                  0
# 1   [18 17 16 15 14 19 21 20 29 28 27]['23' '71' '...                  1
# 2   [18 17 16 15 19 21 20 28 27]['29' '77' '23' '7...                  2
# 3   [20 27 29 28 18 17 16 15 14 13 12 19 21]['28' ...                  3
# 4   [18 17 16 15 14 13 12 19 21 20 28 27]['22' '29...                  4
# 5   [18 17 16 15 19 21 20 29 28 27]['23' '29' '46'...                  5
# 6   [18 17 16 15 19 21 20 28 27]['29' '77' '65' '7...                  6
# 7   [18 17 16 15 19 21 20 29 28 27]['22' '28' '76'...                  7
# 8   [18 17 16 15 19 21 20 29 28 27]['29' '77' '85'...                  8
# 9   [18 17 16 15 14 19 21 20 27 29 28]['76' '22' '...                  9
# 10  [18 17 16 15 19 21 20 29 28 27]['76' '22' '70'...                 10
# 11  [18 17 16 15 14 13 12 19 21 20 27 28 23]['74' ...                 11
# 12  [18 17 16 15 14 13 12 19 21 20 26 25 27 29 28]...                 12
# 13  [18 17 16 15 14 19 21 20 28 27]['70' '23' '77'...                 13
# 14  [18 17 16 15 14 19 21 20 29 28 27]['16' '22' '...                 14
# 15  [18 17 16 15 14 13 12 19 21 20 29 28 27]['76' ...                 15
# 16  [18 17 16 15 19 21 20 29 28 27]['64' '76' '28'...                 16
# 17  [18 17 16 15 14 19 21 20 29 28 27 23]['22' '71...                 17
# 18  [18 17 16 15 19 21 20 29 28 27]['28' '22' '29'...                 18
# 19  [18 17 16 15 19 21 20 29 28 27]['16' '28' '29'...                 19
# 20  [18 17 16 15 14 19 21 20 28 27]['16' '71' '29'...                 20
# 21  [18 17 16 15 19 21 20 29 27]['28' '70' '22' '7...                 21
# 22  [18 17 16 15 19 21 20 29 28 27]['28' '22' '70'...                 22
# 23  [18 17 16 15 14 19 21 20 28 27]['74' '23' '29'...                 23
# 24  [18 17 16 15 14 19 21 20 28 27]['17' '23' '71'...                 24
# 25  [16 14 29 27 18 17 15 26 25]['16' '28' '64' '7...                 25
# 26  [18 17 16 15 14 19 21 20 29 28 27]['22' '70' '...                 26
# 27  [18 17 16 15 19 21 20 23 29 28 27]['22' '70' '...                 27
# 28  [18 17 16 15 14 19 21 20 29 28 27]['70' '17' '...                 28
# 29  [18 17 16 15 14 19 21 20 29 28 27]['22' '76' '...                 29
# 30  [18 17 16 15 19 21 20 29 28 27]['22' '28' '76'...                 30
# 31  [18 17 16 15 19 21 20 29 28 27]['28' '22' '76'...                 31
# 32  [18 17 16 15 19 21 29 28 27]['22' '70' '76' '6...                 32
# 33  [16 18 17 15 19 21]['28' '71' '73' '70' '22' '...                 33
# 34  [18 17 16 15 19 21 20 29 27]['22' '76' '28' '7...                 34
# 35  [18 17 16 15 29 28 27]['28' '76' '29' '71' '22...                 35
# 36  [18 17 16 15 19 21 20 29 27]['64' '28' '76' '2...                 36
# 37  [18 17 16 15 29 28 27]['71' '28' '22' '29' '77...                 37
# 38  [18 17 16 15 29 28 27]['28' '29' '70' '22' '76...                 38
# 39  [18 17 16 15 14 19 21 20 28 27]['71' '23' '74'...                 39
# 40  [18 17 16 15 14 19 21 20 29 28 27 23]['16' '22...                 40
# 41  [18 17 16 15 29 27 19 21]['76' '28' '64' '29' ...                 41
# 42  [18 17 16 15 14 19 21 20 27 29]['76' '28' '22'...                 42
# 43  [18 17 16 29 28 27]['77' '70' '29' '65' '71' '...                 43
# 44  [18 17 16 15 14 13 12 19 21 20 27 29 28]['28' ...                 44
# 45  [18 17 16 15 14 19 21 27 29 28 20]['16' '29' '...                 45
# 46  [18 17 16 15 19 21  4 29]['28' '22' '70' '73' ...                 46
# 47  [18 17 15 19 21 29 20 27]['76' '22' '28' '73' ...                 47
# time: 11 ms

# %%
# read in driving time
import json
with open("drivingTime.txt") as f:
    drivingTime = json.load(f)
# Out:
# time: 10.6 ms

# %%
# routs of the single technicians, List[Lists] calculated by greedy!
indexJob2=[[0, 1, 36, 46, 67],
 [83, 212, 220, 221],
 [16],
 [10, 35, 51, 72, 84, 89, 95, 115, 117, 136],
 [12, 15, 44, 149, 169],
 [31, 52, 68, 75, 121],
 [49, 58, 93, 103],
 [203],
 [11, 25, 37],
 [13, 30, 48, 63, 81, 91, 113, 137],
 [14, 96, 120, 139, 148],
 [17, 20, 33, 87, 106, 126],
 [142, 159, 168],
 [18, 26, 34, 65, 69, 79, 99, 102, 144],
 [131, 156],
 [21, 55, 105, 160],
 [22, 71, 73, 109, 199],
 [23, 57, 104, 177, 200, 206],
 [3, 70, 82, 118, 161, 189, 201],
 [210],
 [88, 129, 202, 213],
 [119, 122, 143, 145, 162, 176, 188, 209, 222],
 [19, 32, 50, 110, 152, 175, 194, 214],
 [140, 170, 182, 185],
 [61, 97, 141],
 [38, 77, 147, 173, 195, 197],
 [2, 40, 66, 90, 135],
 [207, 217, 218, 219],
 [54, 62, 78, 92, 100, 114, 124, 128, 191],
 [64, 80, 101, 112],
 [134, 150, 181],
 [7, 27, 98, 111, 163, 171],
 [190, 208],
 [86, 157, 193, 211],
 [133, 178, 179, 205],
 [28, 53, 85],
 [39, 59, 76, 167, 196, 216],
 [24, 45, 60, 94, 130, 165, 166],
 [6, 29, 56, 127, 138, 164, 183],
 [4, 158, 184],
 [5, 8, 41, 108, 132, 154, 174, 186, 204],
 [9, 116, 146],
 [123, 151, 172, 192, 215],
 [42, 43, 47, 74, 155, 180, 187, 198],
 [107, 125, 153]]
# Out:
# time: 3.41 ms

# %%
# Technician index for the job
indexTech=[16,
 38,
 36,
 34,
 27,
 43,
 39,
 33,
 17,
 30,
 6,
 15,
 32,
 12,
 25,
 24,
 2,
 0,
 7,
 1,
 29,
 40,
 22,
 44,
 35,
 23,
 37,
 13,
 28,
 41,
 21,
 19,
 45,
 10,
 31,
 3,
 18,
 20,
 42,
 14,
 9,
 11,
 26,
 46,
 47]
# Out:
# time: 844 µs

# %%
def Fitness(oneRoute):
    global drivingTime
    scoreTot=0
    singleScore=1
    work_time_alowed=9*60
    for j in range(len(oneRoute)): # over all tech routes

        #hard constrain, skill matching
        if not all(JobsInTime.loc[oneRoute[j],"LX_TCK_RP"].apply(lambda e: e in TechForCalc.loc[indexTech[j],"PRI_QUALIF"])): #JobsInTime["LX_TCK_RP"] in TechForCalc["PRI_QUALIF"] 
            return 0
        
        #soft constrain, drive time
        List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
        List.insert(0,TechForCalc.loc[indexTech[j],"indexHomeLocation"])
        List.append(TechForCalc.loc[indexTech[j],"indexHomeLocation"])
        driveTime=sum([drivingTime[List[x]][List[x+1]] for x in range(len(List)-1)]) # drive time from home to jobs and back to home in Min
        
        #hard constrain, work time per day
        jobDuration =sum(JobsInTime.loc[indexJob[j],"a.jobDuration"]) # count all job durations
        if jobDuration+driveTime > work_time_alowed:
            return 0
            
        scoreTot+=driveTime
             
    return 1/(scoreTot+1)
# Out:
# time: 1.83 ms

# %%
Fitness(indexJob2)
# Out:
# 0.000270929287455974
# time: 90.6 ms

# %%
def breedPopulation(matingpool, eliteSize): # okey for mTPS, constrouct breeded population, hence, breeded routes
    children = []
    length = len(matingpool) - eliteSize
    pool = random.sample(matingpool, len(matingpool))

    for i in range(0,eliteSize): # elite will be taken as it is (no breeding)
        children.append(matingpool[i])
    
    for i in range(0, length): # heer mutithreading, pool find chiled 
        child = breed2(pool[i], pool[len(matingpool)-i-1]) # above was randomly selected, hence here also random
        #print("cild",child)
        children.append(child)
    return children

def breed2(parent1, parent2): # Partialy matched crossover, uaed wenn loction maders # Combine two routes has to be adjusted for mTPS
    
    childP1 = []
    
    faltendP1=[item for sublist in parent1 for item in sublist]
    faltendP2=[item for sublist in parent2 for item in sublist]
    
    geneA = int(random.random() * len(faltendP1)) # index of geen A
    geneB = int(random.random() * len(faltendP2)) # index of geen B   
    startGene = min(geneA, geneB) 
    endGene = max(geneA, geneB)

    for i in range(startGene, endGene):
        childP1.append(faltendP1[i]) # first part of geens
        
    countCP1=0
    childfalttend = [None] * len(faltendP2)
    for i in range(len(faltendP2)):
        if i >= startGene and i < endGene:    
            childfalttend[i] = childP1[countCP1]
            countCP1+=1
        elif faltendP2[i] not in childP1:
            childfalttend[i]=faltendP2[i]
        else:
            index_indP1=faltendP1.index(faltendP2[i])
            #c=0
            while faltendP2[index_indP1] in childP1:
                index_indP1 = faltendP1.index(faltendP2[index_indP1])
                #print(c)
                #c+=1
            childfalttend[i]=faltendP2[index_indP1]
            
    child = []
    counter=0
    for k in range(0,len(parent1)): # Chiled has the same structure as P1
        child.append([])
        for j in range(len(parent1[k])):
            child[k].append(childfalttend[counter])
            counter+=1

    return child
# Out:
# time: 6.01 ms

# %%
Mutated=0
def mutatePopulation(population, mutationRate, eliteSize): # okey for mTPS create mutated population, 
    mutatedPop = []

    global Mutated
    Mutated=0
    
    length_Pop=len(population)
    #for ind in range(length):# range(length_Pop): # len of pop 
    length_Pop=len(population)
    for ind in range(length_Pop):# range(length_Pop): # len of pop 
        mutatedInd = mutate(population[ind], mutationRate)
        mutatedPop.append(mutatedInd)
    #print("mutation rate: ",Mutated/length)# Mutated/length_Pop)
    print("mutation rate: ",Mutated/length_Pop)
    return mutatedPop

def mutate(individualmTPS, mutationRate): # okey for mTPS, check in end to end test
    count=0
    global Mutated
    for individual in individualmTPS: # here a single route is taken
        for swapped in range(len(individual)): # withing the range of the mTPS a swap can ocure
            if(random.random() < mutationRate): # if random is smaller than mutationRate => swap will occure for two cities
                techRoute1= int(random.random() * len(individualmTPS))
                techRoute2= int(random.random() * len(individualmTPS))
                
                swapWith = int(random.random() * len(individual))
                
                if swapWith < len(individualmTPS[techRoute2]) and swapped < len(individualmTPS[techRoute1]):
                    city1 = individualmTPS[techRoute1][swapped]
                    city2 = individualmTPS[techRoute2][swapWith]
                
                    individualmTPS[techRoute1][swapped] = city2
                    individualmTPS[techRoute2][swapWith] = city1
                    count+=1
                    
    # mutate length
    for individual in individualmTPS: # here a single route is taken
        for swapped in range(len(individual)): # withing the range of the mTPS a swap can ocure
            if(random.random() < mutationRate): # if random is smaller than mutationRate => swap will occure for two cities
                techRoute1= int(random.random() * len(individualmTPS))
                techRoute2= int(random.random() * len(individualmTPS))
                
                swapWith = int(random.random() * len(individual))
                
                if swapWith < len(individualmTPS[techRoute2]) and len(individualmTPS[techRoute2]) > 0 : # if here 0 then worker can have no Job
                    city2 = individualmTPS[techRoute2][swapWith]
                     
                    individualmTPS[techRoute1].append(city2)
                    individualmTPS[techRoute2].remove(city2)
                    count+=1

    # mutate internally # consecutive jobs Leo
    for i in range(len(individualmTPS)): # here a single route is taken
        for swapped in range(len(individualmTPS[i])): # withing the range of the mTPS a swap can ocure
            if(random.random() < mutationRate): # if random is smaller than mutationRate => swap will occure for two cities
                
                
                swapWith = int( random.random() * len(individualmTPS[i]) )
                city1 = individualmTPS[i][swapped]
                city2 = individualmTPS[i][swapWith]
                
                individualmTPS[i][swapped] = city2
                individualmTPS[i][swapWith] = city1
                count+=1
    #print("mutated: ", count) 
    if count>0: 
        Mutated+=1
    return individualmTPS
# Out:
# time: 4.03 ms

# %%
def geneticAlgorithm(population, popSize, eliteSize, generations):

    global pop
    global mutationRate
    global TournamentResults
    
    pop = greedyPop(population,popSize) # here population is filed with one solution
    value= Fitness(population) # initial fitness is calculated
    print("Initial: " + str(value))#
    
    count=0
    for i in range(0, generations): # loop over each generation
        TournamentResults = [] 
        pop = nextGeneration(pop, eliteSize, mutationRate)
        
        if count == 49:
            count=0
            print((progress[-1] / value - 1)*100,i)
            value= progress[-1]
        count+=1        
        
    print("Final: " + str( rankRoutes(pop)[0][1] ))# , str(routeDistance2(pop[rankRoutes(pop)[0][0]])) )
    bestRouteIndex = rankRoutes(pop)[0][0] # index of best route
    bestRoute = pop[bestRouteIndex]    
    print(bestRoute)
    return bestRoute
#-------------------------------------------------------------------------------------------------------
def greedyPop(population,popSize):
    greedyP=[]
    for i in range(popSize):
        greedyP.append(population)
    return greedyP

#-------------------------------------------------------------------------------------------------------
import multiprocessing
def nextGeneration(currentGen, eliteSize, mutationRate): # currentGen = pop
    global progress

    manager = multiprocessing.Manager()
    return_dict = manager.dict()
    jobs = []
    for i in range(0,10): # number of turnaments in one generation
        p = multiprocessing.Process(target=Tournament,args=(i,return_dict)) #  args=(,)
        jobs.append(p)
        p.start()
        
    for process in jobs:
        process.join()
    
    fitnessResults = {}
    TournamentResults = return_dict.values()

    for i in range(len(TournamentResults)):
        fitnessResults[i]=TournamentResults[i][0] 
        
    fitnessResultsSorted = sorted(fitnessResults.items(), key = operator.itemgetter(1), reverse = True)

    progress.append(fitnessResultsSorted[0][1])
    print(progress[-1])
    nextGenIndex=creatSelection(fitnessResultsSorted,len(currentGen))
    nextGeneration = []
    for ind in nextGenIndex:
        nextGeneration.append(TournamentResults[ind][1])
    return nextGeneration

#-------------------------------------------------------------------------------------------------------
def Tournament(i,return_dict): # ok
    global pop
    global TournamentResults
    newRoute, fitness = creatAndTournament(pop)
    return_dict[i] = [fitness,newRoute]

def creatAndTournament(currentGen): # ok
    
    comp1,fitness1= creatCompetitor(currentGen) # a valid solution is created
    comp2,fitness2= creatCompetitor(currentGen)
        
    if fitness1 > fitness2: # better solution is choosen
        return comp1, fitness1
    else:
        return comp2, fitness2

def creatCompetitor(currentGen): # ok   
    global mutationRate
    
    NotDone=True
    while NotDone: 
        parent1 =    random.choice(currentGen)
        parent2 =    random.choice(currentGen)
        child = breed2(parent1, parent2) # breeding      
        childMut=mutate(child, mutationRate) # mutation
        fitness=Fitness(childMut) # fitness is calculated
        if fitness > 0:
            return childMut ,fitness
    
#-------------------------------------------------------------------------------------------------------    
def creatSelection(fitnessResults,length):
    total=0
    for e in fitnessResults:
        total+=e[1]
        
    popIndex=[]
    for e in fitnessResults: # fill population with solution, proportional to fitness results 
        for i in range(int(e[0]/total*length)): 
            if len(popIndex) < length:
                popIndex.append(e[0])

    return popIndex
# Out:
# time: 6.6 ms

# %%
import copy
pop=[]

mutationRate=0.001/2
TournamentResults = []
progress=[]

indexJob = copy.deepcopy(indexJob2)

r=geneticAlgorithm(population=indexJob.copy(), popSize=100, eliteSize=10, generations=200)

allSolutions=[]
allSolutions.append(copy.deepcopy(r))
# Out:
# Initial: 0.000270929287455974
# 0.000270929287455974
# 0.00027100271002710027
# 0.00027151778441487917
# 0.00027247956403269756
# 0.00027247956403269756
# 0.00027247956403269756
# 0.00027359781121751026
# 0.0002738975623116954
# 0.0002738975623116954
# 0.0002738975623116954
# 0.0002738975623116954
# 0.0002738975623116954
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027412280701754384
# 0.00027419797093501506
# 0.00027533039647577095
# 0.00027533039647577095
# 0.0002757859900717044
# 0.0002757859900717044
# 0.0002759381898454746
# 0.0002760905577029266
# 0.00027624309392265195
# 0.00027624309392265195
# 0.0002787068004459309
# 0.0002787068004459309
# 0.0002787068004459309
# 0.0002787068004459309
# 0.0002787068004459309
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027925160569673273
# 0.00027925160569673273
# 0.00027925160569673273
# 0.0002794076557697681
# 0.00027925160569673273
# 0.00027925160569673273
# 0.00027925160569673273
# 0.00027925160569673273
# 3.071767662664038 49
# 0.00027925160569673273
# 0.00027925160569673273
# 0.00027925160569673273
# 0.00027925160569673273
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002794076557697681
# 0.0002796420581655481
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.000279876854184159
# 0.000279876854184159
# 0.000279876854184159
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002801905295601009
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.5616399887672152 98
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.0002808199943836001
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.000281135788585887
# 0.0002820078962210942
# 0.0002820078962210942
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.00028208744710860365
# 0.4513399153737607 147
# 0.00028208744710860365
# 0.00028208744710860365
# 0.0002822466836014677
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002824858757062147
# 0.0002827254735651682
# 0.0002827254735651682
# 0.0002827254735651682
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002829654782116582
# 0.0002844950213371266
# 0.0002846569883290635
# 0.91090236265301 196
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# Final: 0.0002844950213371266
# [[46, 1, 36, 0, 67], [83, 212, 52, 221], [16], [10, 35, 51, 72, 84, 95, 89, 115, 117, 136], [12, 15, 44, 149, 169], [68, 220, 31, 75, 121], [58, 49, 93, 103], [203], [37, 25, 11], [63, 30, 91, 13, 81, 48, 113, 137], [148, 96, 120, 139, 14], [17, 33, 87, 20, 106, 126], [142, 159, 168], [26, 18, 34, 69, 65, 79, 99, 102, 144], [156, 131], [55, 105, 160], [22, 71, 73, 109, 199], [23, 57, 104, 177, 200, 206], [3, 70, 82, 118, 161, 189, 201], [210], [88, 129, 202, 213], [119, 122, 143, 145, 162, 176, 188, 209, 222], [19, 32, 50, 110, 194, 175, 152, 214], [185, 170, 182, 140], [61, 97, 141], [197, 207, 147, 173, 195, 38, 21], [40, 2, 66, 90, 135], [217, 77, 218, 219], [54, 62, 78, 92, 100, 114, 124, 128, 191], [101, 80, 64, 112], [134, 150, 181], [7, 27, 98, 111, 163, 171], [190, 208], [193, 157, 86, 211], [133, 178, 179, 205], [28, 53, 85], [39, 59, 76, 167, 196, 216], [60, 45, 24, 94, 130, 165, 166], [138, 29, 56, 6, 127, 164, 183], [4, 158, 184], [5, 8, 41, 108, 132, 154, 174, 186, 204], [116, 9, 146], [172, 151, 123, 192, 215], [187, 43, 47, 74, 155, 42, 180, 198], [107, 125, 153]]
# time: 1min 49s

# %%
plt.plot(progress)
plt.ylabel('Distance')
plt.xlabel('Generation')
plt.show()
print(len(progress))
r
# Out:
# 100
# [[0, 1, 36, 46, 67],
#  [83, 212, 220, 221],
#  [16],
#  [10, 35, 51, 72, 84, 89, 95, 115, 117, 136],
#  [12, 15, 44, 149, 169],
#  [31, 52, 68, 75, 121],
#  [49, 58, 93, 103],
#  [203],
#  [11, 25, 37],
#  [13, 30, 81, 91, 48, 63, 113, 137],
#  [14, 96, 120, 139, 148],
#  [17, 33, 20, 87, 106, 126],
#  [142, 159, 168],
#  [18, 26, 65, 34, 69, 79, 99, 102, 144],
#  [131, 156],
#  [21, 55, 105, 160],
#  [22, 71, 73, 109, 199],
#  [23, 57, 104, 177, 200, 206],
#  [3, 70, 82, 118, 161, 189, 201],
#  [210],
#  [88, 64, 202, 213],
#  [119, 122, 143, 145, 162, 176, 188, 209, 222],
#  [19, 32, 50, 110, 194, 175, 152, 214],
#  [140, 170, 182, 185],
#  [61, 97, 141],
#  [38, 77, 147, 173, 195, 197],
#  [2, 40, 66, 90, 135],
#  [218, 217, 207, 219],
#  [54, 62, 78, 92, 100, 114, 124, 128, 191],
#  [129, 80, 101, 112],
#  [134, 150, 181],
#  [27, 7, 98, 111, 163, 171],
#  [190, 208],
#  [86, 157, 193, 211],
#  [133, 178, 179, 205],
#  [28, 53, 85],
#  [76, 59, 39, 167, 196, 216],
#  [24, 45, 60, 94, 130, 165, 166],
#  [6, 29, 56, 127, 138, 164, 183],
#  [4, 158, 184],
#  [8, 5, 41, 108, 132, 154, 174, 186, 204],
#  [116, 9, 146],
#  [172, 151, 123, 192, 215],
#  [42, 43, 47, 74, 155, 187, 180, 198],
#  [153, 125, 107]]
# time: 126 ms

# %%
# continue optimizing
for i in range(len(allSolutions)-1,len(allSolutions)+1000):
    t=geneticAlgorithm(population=copy.deepcopy(allSolutions[i]), popSize=100, eliteSize=10, generations=500)
    allSolutions.append( copy.deepcopy(t) )
    print(allSolutions[-1])
# Out:
# Initial: 0.00027731558513588466
# 0.00027731558513588466
# 0.00027731558513588466
# 0.0002778549597110308
# 0.00027800945232137893
# 0.00027800945232137893
# 0.00027808676307007786
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.0002782415136338342
# 0.00027831895352073476
# 0.00027831895352073476
# 0.00027839643652561246
# 0.00027839643652561246
# 0.00027839643652561246
# 0.00027839643652561246
# 0.00027839643652561246
# 0.0002788622420524261
# 0.0002788622420524261
# 0.0002789400278940028
# 0.0002789400278940028
# 0.0002789400278940028
# 0.0002789400278940028
# 0.0002789400278940028
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027917364600781687
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.00027932960893854746
# 0.0002797985450475658
# 0.8953553441522155 49
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.0002797985450475658
# 0.000279876854184159
# 0.000279876854184159
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.5627462014631268 98
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.0002813731007315701
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.00028153153153153153
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.0002828054298642534
# 0.5090497737556543 147
# 0.0002828054298642534
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.0002840909090909091
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.00028392958546280523
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002840909090909091
# 0.0002843332385555871
# 0.0002843332385555871
# 0.0002843332385555871
# 0.0002843332385555871
# 0.0002844950213371266
# 0.0002844950213371266
# 0.5974395448079761 196
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# 0.0002844950213371266
# Process Process-3431:
# Process Process-3427:
# Process Process-3430:
# Process Process-3426:
# Process Process-3424:
# Process Process-3425:
# Process Process-3423:
# Process Process-3429:
# Process Process-3428:
# Process Process-3432:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-7b703217eff7>", line 40, in creatAndTournament
#     comp1,fitness1= creatCompetitor(currentGen)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-9-7b703217eff7>", line 41, in creatAndTournament
#     comp2,fitness2= creatCompetitor(currentGen)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-7b703217eff7>", line 41, in creatAndTournament
#     comp2,fitness2= creatCompetitor(currentGen)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-9-7b703217eff7>", line 40, in creatAndTournament
#     comp1,fitness1= creatCompetitor(currentGen)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-10-6fff32fb84bf>", line 16, in Fitness
#     driveTime=sum([drivingTime[List[x]][List[x+1]] for x in range(len(List)-1)]) # drive time from home to jobs and back to home in Min
#   File "<ipython-input-9-7b703217eff7>", line 41, in creatAndTournament
#     comp2,fitness2= creatCompetitor(currentGen)
#   File "<ipython-input-9-7b703217eff7>", line 40, in creatAndTournament
#     comp1,fitness1= creatCompetitor(currentGen)
# Traceback (most recent call last):
#   File "<ipython-input-9-7b703217eff7>", line 40, in creatAndTournament
#     comp1,fitness1= creatCompetitor(currentGen)
#   File "<ipython-input-9-7b703217eff7>", line 41, in creatAndTournament
#     comp2,fitness2= creatCompetitor(currentGen)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "<ipython-input-10-6fff32fb84bf>", line 9, in Fitness
#     if not all(JobsInTime.loc[oneRoute[j],"LX_TCK_RP"].apply(lambda e: e in TechForCalc.loc[indexTech[j],"PRI_QUALIF"])): #JobsInTime["LX_TCK_RP"] in TechForCalc["PRI_QUALIF"]
#   File "<ipython-input-10-6fff32fb84bf>", line 13, in Fitness
#     List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
#   File "<ipython-input-9-7b703217eff7>", line 64, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-10-6fff32fb84bf>", line 16, in <listcomp>
#     driveTime=sum([drivingTime[List[x]][List[x+1]] for x in range(len(List)-1)]) # drive time from home to jobs and back to home in Min
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "<ipython-input-9-7b703217eff7>", line 41, in creatAndTournament
#     comp2,fitness2= creatCompetitor(currentGen)
#   File "<ipython-input-10-6fff32fb84bf>", line 13, in Fitness
#     List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/base.py", line 1113, in tolist
#     return self._values.tolist()
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/series.py", line 3591, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#   File "<ipython-input-10-6fff32fb84bf>", line 19, in Fitness
#     jobDuration =sum(JobsInTime.loc[indexJob[j],"a.jobDuration"]) # count all job durations
#   File "<ipython-input-10-6fff32fb84bf>", line 13, in Fitness
#     List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-10-6fff32fb84bf>", line 13, in Fitness
#     List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
#   File "<ipython-input-10-6fff32fb84bf>", line 13, in Fitness
#     List= JobsInTime.loc[oneRoute[j],"indexJobLocation"].tolist()
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/base.py", line 1108, in tolist
#     if is_datetimelike(self._values):
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "<ipython-input-9-7b703217eff7>", line 31, in Tournament
#     newRoute, fitness = creatAndTournament(pop)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "<ipython-input-10-6fff32fb84bf>", line 9, in Fitness
#     if not all(JobsInTime.loc[oneRoute[j],"LX_TCK_RP"].apply(lambda e: e in TechForCalc.loc[indexTech[j],"PRI_QUALIF"])): #JobsInTime["LX_TCK_RP"] in TechForCalc["PRI_QUALIF"]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 741, in is_datetimelike
#     return (is_datetime64_dtype(arr) or is_datetime64tz_dtype(arr) or
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 431, in is_datetime64_dtype
#     return _is_dtype_type(arr_or_dtype, classes(np.datetime64))
#   File "<ipython-input-9-7b703217eff7>", line 40, in creatAndTournament
#     comp1,fitness1= creatCompetitor(currentGen)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 1882, in _is_dtype_type
#     tipo = pandas_dtype(arr_or_dtype).type
#   File "<ipython-input-9-7b703217eff7>", line 57, in creatCompetitor
#     fitness=Fitness(childMut)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
# KeyboardInterrupt
#   File "<ipython-input-10-6fff32fb84bf>", line 9, in Fitness
#     if not all(JobsInTime.loc[oneRoute[j],"LX_TCK_RP"].apply(lambda e: e in TechForCalc.loc[indexTech[j],"PRI_QUALIF"])): #JobsInTime["LX_TCK_RP"] in TechForCalc["PRI_QUALIF"]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1494, in __getitem__
#     return self._getitem_tuple(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1205, in _getitem_iterable
#     raise_missing=False)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1205, in _getitem_iterable
#     raise_missing=False)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1205, in _getitem_iterable
#     raise_missing=False)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1205, in _getitem_iterable
#     raise_missing=False)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 868, in _getitem_tuple
#     return self._getitem_lowerdim(tup)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1154, in _get_listlike_indexer
#     indexer = ax.get_indexer_for(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1154, in _get_listlike_indexer
#     indexer = ax.get_indexer_for(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1154, in _get_listlike_indexer
#     indexer = ax.get_indexer_for(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1154, in _get_listlike_indexer
#     indexer = ax.get_indexer_for(key)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1017, in _getitem_lowerdim
#     return getattr(section, self.name)[new_key]
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1207, in _getitem_iterable
#     copy=True, allow_dups=True)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 4455, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 4455, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 4455, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 4455, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2718, in get_indexer
#     target = ensure_index(target)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 4495, in _reindex_with_indexers
#     return self._constructor(new_data).__finalize__(self)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2718, in get_indexer
#     target = ensure_index(target)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2718, in get_indexer
#     target = ensure_index(target)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2718, in get_indexer
#     target = ensure_index(target)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 5364, in ensure_index
#     converted, all_arrays = lib.clean_index_list(index_like)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 5050, in __finalize__
#     object.__setattr__(self, name, getattr(other, name, None))
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 5364, in ensure_index
#     converted, all_arrays = lib.clean_index_list(index_like)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 5364, in ensure_index
#     converted, all_arrays = lib.clean_index_list(index_like)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1902, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 5364, in ensure_index
#     converted, all_arrays = lib.clean_index_list(index_like)
#   File "pandas/_libs/lib.pyx", line 643, in pandas._libs.lib.clean_index_list
#   File "pandas/_libs/lib.pyx", line 643, in pandas._libs.lib.clean_index_list
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py", line 1207, in _getitem_iterable
#     copy=True, allow_dups=True)
#   File "pandas/_libs/lib.pyx", line 643, in pandas._libs.lib.clean_index_list
#   File "pandas/_libs/lib.pyx", line 1230, in pandas._libs.lib.infer_dtype
#   File "pandas/_libs/lib.pyx", line 643, in pandas._libs.lib.clean_index_list
#   File "pandas/_libs/lib.pyx", line 1230, in pandas._libs.lib.infer_dtype
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 4490, in _reindex_with_indexers
#     copy=copy)
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "pandas/_libs/lib.pyx", line 1232, in pandas._libs.lib.infer_dtype
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "pandas/_libs/lib.pyx", line 1230, in pandas._libs.lib.infer_dtype
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1213, in construct_1d_object_array_from_listlike
#     result = np.empty(len(values), dtype='object')
#   File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1231, in reindex_indexer
#     fill_tuple=(fill_value,))
#   File "<frozen importlib._bootstrap>", line 980, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 898, in _find_spec
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap>", line 148, in __enter__
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1270, in _slice_take_blocks_ax0
#     fill_tuple=fill_tuple)]
#   File "<frozen importlib._bootstrap>", line 906, in _find_spec
#   File "<frozen importlib._bootstrap>", line 174, in _get_module_lock
#   File "<frozen importlib._bootstrap>", line 855, in __enter__
#   File "<frozen importlib._bootstrap_external>", line 1280, in find_spec
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py", line 1238, in take_nd
#     allow_fill=True, fill_value=fill_value)
#   File "<frozen importlib._bootstrap>", line 59, in __init__
#   File "<frozen importlib._bootstrap_external>", line 1252, in _get_spec
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py", line 1654, in take_nd
#     mask_info=mask_info)
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap_external>", line 1391, in find_spec
#   File "/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py", line 1419, in _get_take_nd_function
#     tup = (arr_dtype.name, out_dtype.name)
# KeyboardInterrupt
#   File "/anaconda3/lib/python3.7/site-packages/numpy/core/_dtype.py", line 319, in _name_get
#     def _name_get(dtype):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-0d0af0e45b44> in <module>
#       1 # continue optimizing
#       2 for i in range(len(allSolutions)-1,len(allSolutions)+1000):
# ----> 3     t=geneticAlgorithm(population=copy.deepcopy(allSolutions[i]), popSize=100, eliteSize=10, generations=500)
#       4     allSolutions.append( copy.deepcopy(t) )
#       5     print(allSolutions[-1])
#
# <ipython-input-9-7b703217eff7> in geneticAlgorithm(population, popSize, eliteSize, generations)
#      12     for i in range(0, generations):
#      13         TournamentResults = []
# ---> 14         pop = nextGeneration(pop, eliteSize, mutationRate)
#      15
#      16         if count == 49:
#
# <ipython-input-9-7b703217eff7> in nextGeneration(currentGen, eliteSize, mutationRate)
#      95
#      96     for process in jobs:
# ---> 97         process.join()
#      98
#      99     #time.sleep(2)
#
# /anaconda3/lib/python3.7/multiprocessing/process.py in join(self, timeout)
#     138         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     139         assert self._popen is not None, 'can only join a started process'
# --> 140         res = self._popen.wait(timeout)
#     141         if res is not None:
#     142             _children.discard(self)
#
# /anaconda3/lib/python3.7/multiprocessing/popen_fork.py in wait(self, timeout)
#      46                     return None
#      47             # This shouldn't block if wait() returned successfully.
# ---> 48             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      49         return self.returncode
#      50
#
# /anaconda3/lib/python3.7/multiprocessing/popen_fork.py in poll(self, flag)
#      26         if self.returncode is None:
#      27             try:
# ---> 28                 pid, sts = os.waitpid(self.pid, flag)
#      29             except OSError as e:
#      30                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
# time: 1min 38s
